# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Environment\AI PROJECT\creditcard.csv")
sample_df = df.sample(n=5000, random_state=42)

# %%
sample_df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
sample_df.head(3)
# Out:
#           Time         V1        V2         V3        V4         V5        V6  \
# 43428  41505.0 -16.526507  8.584972 -18.649853  9.505594 -13.793819 -2.832404
# 49906  44261.0   0.339812 -2.743745  -0.134070 -1.385729  -1.451413  1.015887
# 29474  35484.0   1.399590 -0.590701   0.168619 -1.029950  -0.539806  0.040444
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 43428 -16.701694  7.517344 -8.507059  ...  1.190739 -1.127670 -2.358579
# 49906  -0.524379  0.224060  0.899746  ... -0.213436 -0.942525 -0.526819
# 29474  -0.712567  0.002299 -0.971747  ...  0.102398  0.168269 -0.166639
#
#             V24       V25       V26       V27       V28  Amount  Class
# 43428  0.673461 -1.413700 -0.462762 -2.018575 -1.042804  364.19      1
# 49906 -1.156992  0.311211 -0.746647  0.040996  0.102038  520.12      0
# 29474 -0.810250  0.505083 -0.232340  0.011409  0.004634   31.00      0
#
# [3 rows x 31 columns]

# %%
sample_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, 43428 to 98463
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    5000 non-null   float64
#  1   V1      5000 non-null   float64
#  2   V2      5000 non-null   float64
#  3   V3      5000 non-null   float64
#  4   V4      5000 non-null   float64
#  5   V5      5000 non-null   float64
#  6   V6      5000 non-null   float64
#  7   V7      5000 non-null   float64
#  8   V8      5000 non-null   float64
#  9   V9      5000 non-null   float64
#  10  V10     5000 non-null   float64
#  11  V11     5000 non-null   float64
#  12  V12     5000 non-null   float64
#  13  V13     5000 non-null   float64
#  14  V14     5000 non-null   float64
#  15  V15     5000 non-null   float64
#  16  V16     5000 non-null   float64
#  17  V17     5000 non-null   float64
#  18  V18     5000 non-null   float64
#  19  V19     5000 non-null   float64
# ...

# %%
sample_df.describe()
# Out:
#                 Time           V1           V2           V3           V4  \
# count    5000.000000  5000.000000  5000.000000  5000.000000  5000.000000
# mean    94557.283800    -0.014196    -0.000891     0.000648     0.011844
# std     47086.875638     1.948877     1.752375     1.455444     1.386241
# min        23.000000   -32.058119   -48.060856   -18.649853    -4.629003
# 25%     53973.000000    -0.941203    -0.588854    -0.906400    -0.824201
# 50%     84402.500000     0.036581     0.096409     0.160341    -0.015156
# 75%    138888.250000     1.314442     0.804390     1.027443     0.746837
# max    172782.000000     2.368294     9.252013     3.760965    10.856608
#
#                 V5           V6           V7           V8           V9  ...  \
# count  5000.000000  5000.000000  5000.000000  5000.000000  5000.000000  ...
# mean      0.025717    -0.027056     0.015709    -0.001811     0.006753  ...
# std       1.390851     1.319011     1.157703     1.068458     1.081889  ...
# ...

# %%
sample_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('Class',axis=1)
y = df['Class']

# %%
#Decision Tree Model, training
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %% [markdown]
# ## Prediction and Evaluation

# %%
predictions = dtree.predict(X_test)

# %%
print("Predictions array: ",predictions)
# Out:
# Predictions array:  [0 0 0 ... 0 0 0]

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85286
#            1       0.76      0.73      0.75       157
#
#     accuracy                           1.00     85443
#    macro avg       0.88      0.87      0.87     85443
# weighted avg       1.00      1.00      1.00     85443

# %%
print(classification_report(y_test,predictions))
# Out:
# [[85250    36]
#  [   42   115]]

# %%
from sklearn import tree
plt.figure(figsize=(20,25))
tree.plot_tree(dtree,feature_names=X.columns,class_names=['Class-1', 'Class-0'],rounded=True, # Rounded node edges
          filled=True, # Adds color according to class
          proportion=True
        )
plt.show()

# %%
user_input = [float(x) for x in input("Enter 30 feature values separated by commas: ").split(",")]
user_input_df = pd.DataFrame([user_input], columns=X.columns)  # Use same feature names
result = dtree.predict(user_input_df)

print("Prediction:", "Fraud" if result[0] == 1 else "Not Fraud")
# Out:
# Enter 30 feature values separated by commas:  -1.359807,-0.072781,2.536346,1.378155,-0.338321,0.462388,0.239599,0.098698,0.363787,0.090794, -0.5516,-0.617801,-0.99139,-0.311169,1.468177,-0.4704,0.207971,0.025791,0.403993,0.251412, -0.018307,0.277838,-0.110474,0.066928,0.128539,-0.189115,0.133558,-0.021053,149.62,0
# Prediction: Not Fraud
